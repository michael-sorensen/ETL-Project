# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#import month data

# %%
csv_file = "Months/apr_df_new.csv"
apr_data_df = pd.read_csv(csv_file)
apr_data_df.head()
# Out:
#         State  adh_APRavg  tot_cases_Apr  strictAprPol  maskAPR75  \
# 0     Alabama       24.67           7306           NaN        NaN
# 1      Alaska       33.30            355           NaN        NaN
# 2     Arizona       14.90           7648           NaN        NaN
# 3    Arkansas       27.57           3255           NaN        NaN
# 4  California       38.07          48917           NaN        NaN
#
#    Wk_case_rate_Apr  MaskAprPol  Wk_AprHI  case_rate_Apr    Month
# 0               NaN         NaN       NaN            NaN  2020-04
# 1               NaN         NaN       NaN            NaN  2020-04
# 2               NaN         NaN       NaN            NaN  2020-04
# 3               NaN         NaN       NaN            NaN  2020-04
# 4               NaN         NaN       NaN            NaN  2020-04

# %%
csv_file = "Months/may_df_new.csv"
may_data_df = pd.read_csv(csv_file)
may_data_df.head()
# Out:
#         State  tot_cases_May  case_rate_May  Wk_case_rate_May  Wk_MayHI  \
# 0     Alabama          18245     223.099883        101.409038         0
# 1      Alaska            460      14.353184          6.524175         0
# 2     Arizona          19936     168.820961         76.736801         0
# 3    Arkansas           7253     132.480439         60.218382         0
# 4  California         110583     156.068161         70.940073         0
#
#    adh_MAYavg  MaskMayPol  maskMAY75  strictMayPol    Month
# 0         NaN         NaN        NaN           NaN  2020-05
# 1         NaN         NaN        NaN           NaN  2020-05
# 2         NaN         NaN        NaN           NaN  2020-05
# 3         NaN         NaN        NaN           NaN  2020-05
# 4         NaN         NaN        NaN           NaN  2020-05

# %%
csv_file = "Months/jun_df_new.csv"
jun_data_df = pd.read_csv(csv_file)
jun_data_df.head()
# Out:
#         State  adh_JUNEavg  tot_cases_Jun  case_rate_Jun  MaskJunPol  \
# 0     Alabama        27.60          38064     404.206653           0
# 1      Alaska        46.03            940      65.614555           1
# 2     Arizona        21.77          79215     814.415508           0
# 3    Arkansas        36.90          20777     448.140436           0
# 4  California        48.70         222917     284.301898           1
#
#    Wk_case_rate_Jun  Wk_JunHI  maskGT75  strictJunPol    Month
# 0        183.730297         0         0             0  2020-06
# 1         29.824798         0         0             0  2020-06
# 2        370.188867         1         1             0  2020-06
# 3        203.700198         1         0             0  2020-06
# 4        129.228136         0         0             0  2020-06

# %%
csv_file = "Months/jul_df_new.csv"
july_data_df = pd.read_csv(csv_file)
july_data_df.head()
# Out:
#         State  adh_JULavg  tot_Cases_Jul  case_rate_Jul  MaskJulPol  \
# 0     Alabama   62.677419          87867    1015.727532           1
# 1      Alaska   57.451613           2990     280.228831           1
# 2     Arizona   83.129032         174010    1302.358644           0
# 3    Arkansas   58.258065          42511     720.192564           1
# 4  California   74.290323         493588     685.031060           1
#
#    Wk_case_rate_Jul  Wk_JulHI  maskJUL75  strictJulPol    Month
# 0        461.694333         1          0             0  2020-07
# 1        127.376741         0          0             1  2020-07
# 2        591.981202         1          1             0  2020-07
# 3        327.360256         1          0             1  2020-07
# 4        311.377754         1          0             0  2020-07

# %%
csv_file = "Months/aug_df_new.csv"
aug_data_df = pd.read_csv(csv_file)
aug_data_df.head()
# Out:
#         State  adh_AUGavg  tot_cases_Aug  case_rate_Aug  MaskAugPol  \
# 0     Alabama   65.354839         126058     778.901877           1
# 1      Alaska   56.838710           5263     310.712260           1
# 2     Arizona   87.258065         201835     382.278910           0
# 3    Arkansas   59.000000          61224     620.086659           1
# 4  California   74.612903         704085     532.738945           1
#
#    Wk_case_rate_Aug  Wk_AugHI  maskAUG75  strictAugPol    Month
# 0        354.046308         1          0           NaN  2020-08
# 1        141.232845         0          0           1.0  2020-08
# 2        173.763141         0          1           NaN  2020-08
# 3        281.857572         1          0           1.0  2020-08
# 4        242.154066         1          0           NaN  2020-08

# %%
csv_file = "Months/sep_df_new.csv"
sep_data_df = pd.read_csv(csv_file)
sep_data_df.head()
# Out:
#         State  AdhSEPavg  tot_cases_Sep  case_rate_Sep  MaskSepPol  \
# 0     Alabama      59.83         154701     584.171309           1
# 1      Alaska      52.33           7824     350.080993           1
# 2     Arizona      67.97         218507     229.051356           0
# 3    Arkansas      60.20          83697     744.680569           1
# 4  California      72.47         810625     269.638081           1
#
#    Wk_case_rate_Sep  Wk_SepHI  maskSEP75  strictSepPol    Month
# 0        265.532413         1          0           NaN  2020-09
# 1        159.127724         0          0           1.0  2020-09
# 2        104.114253         0          0           NaN  2020-09
# 3        338.491168         1          0           1.0  2020-09
# 4        122.562764         0          0           NaN  2020-09

# %%
csv_file = "Months/oct_df_new.csv"
oct_data_df = pd.read_csv(csv_file)
oct_data_df.head()
# Out:
#         State  tot_cases_Oct  case_rate_Oct  Wk_case_rate_Oct  Wk_OctHI  \
# 0     Alabama         192285     766.522169        348.419168         1
# 1      Alaska          15274    1018.392580        462.905718         1
# 2     Arizona         245946     376.975777        171.352626         0
# 3    Arkansas         112190     944.163372        429.165169         1
# 4  California         922005     281.887455        128.130662         0
#
#    maskOCT75  maskOctPol  adh_OCTavg  strictOctpol    Month
# 0        NaN         NaN         NaN           NaN  2020-10
# 1        NaN         NaN         NaN           NaN  2020-10
# 2        NaN         NaN         NaN           NaN  2020-10
# 3        NaN         NaN         NaN           NaN  2020-10
# 4        NaN         NaN         NaN           NaN  2020-10

# %%
#import twitter data

# %%
csv_file = "tweets_final.csv"
tweets_final_df = pd.read_csv(csv_file)
tweets_final_df.head()
# Out:
#    Unnamed: 0      tweet.id                 tweet.date  \
# 0           0  1.266430e+18  2020-05-29 18:02:15+00:00
# 1           5  1.264970e+18  2020-05-25 17:11:58+00:00
# 2           6  1.264640e+18  2020-05-24 19:35:47+00:00
# 3           7  1.264600e+18  2020-05-24 16:35:36+00:00
# 4           8  1.264600e+18  2020-05-24 16:35:36+00:00
#
#                                              content  tweet.username  \
# 0  Calling on @realDonaldTrump to end the #CDC #m...  di_daisyistand
# 1  @BillKristol Kristol adores Mob Rule. People w...  JuliaHaverinen
# 2  If you worked anywhere near the public during ...  di_daisyistand
# 3  And, STOP lying and telling us this is to “sav...  di_daisyistand
# 4  @realDonaldTrump needs to fire DrBirx and her ...  di_daisyistand
#
#             user.location       user.id    month     state    Month  Positive  \
# 0  Southern Colorado, USA  3.072081e+09  2020-05  Colorado  2020-05     0.132
# 1      Singed Pole, Maine  8.563473e+08  2020-05     Maine  2020-05     0.178
# 2  Southern Colorado, USA  3.072081e+09  2020-05  Colorado  2020-05     0.038
# 3  Southern Colorado, USA  3.072081e+09  2020-05  Colorado  2020-05     0.000
# 4  Southern Colorado, USA  3.072081e+09  2020-05  Colorado  2020-05     0.083
#
#    Negative  Neutral  Compound
# 0     0.000    0.868    0.6487
# 1     0.000    0.822    0.3818
# 2     0.000    0.962    0.0572
# 3     0.213    0.787   -0.8832
# 4     0.335    0.581   -0.9450

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/Mask_Data')
conn = engine.connect()

# %%
engine.table_names()
# Out:
# <ipython-input-13-d72bc75a6b62>:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['april', 'may', 'june', 'july', 'august', 'september', 'tweets', 'october']

# %%
apr_data_df.to_sql(name='april', con=engine, if_exists='append', index=False)
may_data_df.to_sql(name='may', con=engine, if_exists='append', index=False)
jun_data_df.to_sql(name='june', con=engine, if_exists='append', index=False)
july_data_df.to_sql(name='july', con=engine, if_exists='append', index=False)
aug_data_df.to_sql(name='august', con=engine, if_exists='append', index=False)
sep_data_df.to_sql(name='september', con=engine, if_exists='append', index=False)
oct_data_df.to_sql(name='october', con=engine, if_exists='append', index=False)

# %%
tweets_final_df.to_sql(name='tweets', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#
# UniqueViolation: duplicate key value violates unique constraint "tweets_pkey"
# DETAIL:  Key (state, "Month")=(Colorado, 2020-05) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-16-cc9b8e6858bb> in <module>
# ----> 1 tweets_final_df.to_sql(name='tweets', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                             break
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     901                 kwargs = {}
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#     905                 statement,
#
# ~\anaconda3\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
# -> 1270         cur.execute(b''.join(parts))
#    1271         if fetch:
#    1272             result.extend(cur.fetchall())
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "tweets_pkey"
# DETAIL:  Key (state, "Month")=(Colorado, 2020-05) already exists.
#
# [SQL: INSERT INTO tweets ("Unnamed: 0", "tweet.id", "tweet.date", content, "tweet.username", "user.location", "user.id", month, state, "Month", "Positive", "Negative", "Neutral", "Compound") VALUES (%(Unnamed: 0)s, %(tweet.id)s, %(tweet.date)s, %(content)s, %(tweet.username)s, %(user.location)s, %(user.id)s, %(month)s, %(state)s, %(Month)s, %(Positive)s, %(Negative)s, %(Neutral)s, %(Compound)s)]
# [parameters: ({'Unnamed: 0': 0, 'tweet.id': 1.26643e+18, 'tweet.date': '2020-05-29 18:02:15+00:00', 'content': "Calling on @realDonaldTrump to end the #CDC #maskmandate (which NEVER made any sense!) If people don't have symptoms they don't have #covid and the authorities are playing #publichealth ground-hog &amp;witch-hunt. End this! Please, #replacetheleadership at CDC! #firemaskers", 'tweet.username': 'di_daisyistand', 'user.location': 'Southern Colorado, USA', 'user.id': 3072080773.0, 'month': '2020-05', 'state': 'Colorado', 'Month': '2020-05', 'Positive': 0.132, 'Negative': 0.0, 'Neutral': 0.868, 'Compound': 0.6487}, {'Unnamed: 0': 5, 'tweet.id': 1.26497e+18, 'tweet.date': '2020-05-25 17:11:58+00:00', 'content': '@BillKristol Kristol adores Mob Rule. People with Asthma are exempted from #MaskMandate. #Kristol_Stoopid', 'tweet.username': 'JuliaHaverinen', 'user.location': 'Singed Pole, Maine', 'user.id': 856347266.0, 'month': '2020-05', 'state': 'Maine', 'Month': '2020-05', 'Positive': 0.178, 'Negative': 0.0, 'Neutral': 0.822, 'Compound': 0.3818}, {'Unnamed: 0': 6, 'tweet.id': 1.26464e+18, 'tweet.date': '2020-05-24 19:35:47+00:00', 'content': 'If you worked anywhere near the public during our "#lockdowns" you may be delusional if you believe you HAVEN\'T been exposed to #covid19. The #maskmandate (forcing everyone) is based on a lie.', 'tweet.username': 'di_daisyistand', 'user.location': 'Southern Colorado, USA', 'user.id': 3072080773.0, 'month': '2020-05', 'state': 'Colorado', 'Month': '2020-05', 'Positive': 0.038, 'Negative': 0.0, 'Neutral': 0.962, 'Compound': 0.0572}, {'Unnamed: 0': 7, 'tweet.id': 1.2646e+18, 'tweet.date': '2020-05-24 16:35:36+00:00', 'content': 'And, STOP lying and telling us this is to “save individual lives”-When #CDC &amp; #publichealth is only for protecting #government and it’s structure period. Not #USCitizens health or lives! If it were there would NEVER have been this deceitful #maskmandate! #endBirxscashcow', 'tweet.username': 'di_daisyistand', 'user.location': 'Southern Colorado, USA', 'user.id': 3072080773.0, 'month': '2020-05', 'state': 'Colorado', 'Month': '2020-05', 'Positive': 0.0, 'Negative': 0.213, 'Neutral': 0.787, 'Compound': -0.8832}, {'Unnamed: 0': 8, 'tweet.id': 1.2646e+18, 'tweet.date': '2020-05-24 16:35:36+00:00', 'content': '@realDonaldTrump needs to fire DrBirx and her lousy #maskmandate that covers her &amp; #CDC’s complete and deadly incompetence  in choosing a killer model for self-multiplied crisis #pandemictriage call. Her lack of ability to call it, treat it, or check their own harmful procedures!', 'tweet.username': 'di_daisyistand', 'user.location': 'Southern Colorado, USA', 'user.id': 3072080773.0, 'month': '2020-05', 'state': 'Colorado', 'Month': '2020-05', 'Positive': 0.083, 'Negative': 0.335, 'Neutral': 0.581, 'Compound': -0.945}, {'Unnamed: 0': 9, 'tweet.id': 1.26384e+18, 'tweet.date': '2020-05-22 14:17:45+00:00', 'content': 'Live from #RVA. #Masks #Virginia #MaskMandate. Triggering warning! (5/22/20) https://t.co/cSds5Dx8jR', 'tweet.username': 'Rumpleventure', 'user.location': 'Virginia USA', 'user.id': 1.23493e+18, 'month': '2020-05', 'state': 'Virginia', 'Month': '2020-05', 'Positive': 0.0, 'Negative': 0.23, 'Neutral': 0.77, 'Compound': -0.4003}, {'Unnamed: 0': 10, 'tweet.id': 1.26283e+18, 'tweet.date': '2020-05-19 19:58:08+00:00', 'content': 'Stop the #maskmandate-ONLY people who BELIEVE a mask will help THEM should wear one! NO ONE ELSE SHOULD BE FORCED! This is one of the most offensive and bogus mandates! And, #forcedmasks should be carefully investigated as factor in the death at #nursingcenters! #endmeasures', 'tweet.username': 'di_daisyistand', 'user.location': 'Southern Colorado, USA', 'user.id': 3072080773.0, 'month': '2020-05', 'state': 'Colorado', 'Month': '2020-05', 'Positive': 0.072, 'Negative': 0.295, 'Neutral': 0.633, 'Compound': -0.9328}, {'Unnamed: 0': 11, 'tweet.id': 1.26283e+18, 'tweet.date': '2020-05-19 19:30:54+00:00', 'content': 'Continued  ...
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %%
#export data into csv
cities_data_df.to_csv('Output_Data/cities_df.csv', index = False)
